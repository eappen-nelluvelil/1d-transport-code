# %%
import gmsh

# Initialize the Gmsh API
gmsh.initialize()

# Create a new model
gmsh.model.add("Unit Square")

# Define the vertices of the square (points)
p1 = gmsh.model.geo.addPoint(0, 0, 0)  # Point (0, 0)
p2 = gmsh.model.geo.addPoint(1, 0, 0)  # Point (1, 0)
p3 = gmsh.model.geo.addPoint(1, 1, 0)  # Point (1, 1)
p4 = gmsh.model.geo.addPoint(0, 1, 0)  # Point (0, 1)

# Create the lines (edges) of the square
l1 = gmsh.model.geo.addLine(p1, p2)  # Line between (0, 0) and (1, 0)
l2 = gmsh.model.geo.addLine(p2, p3)  # Line between (1, 0) and (1, 1)
l3 = gmsh.model.geo.addLine(p3, p4)  # Line between (1, 1) and (0, 1)
l4 = gmsh.model.geo.addLine(p4, p1)  # Line between (0, 1) and (0, 0)

# Create a curve loop to define the boundary of the square
loop = gmsh.model.geo.addCurveLoop([l1, l2, l3, l4])

# Create a plane surface for the square
surface = gmsh.model.geo.addPlaneSurface([loop])

# Synchronize the CAD kernel
gmsh.model.geo.synchronize()

# Define a mesh size field (optional)
# You can define a uniform or non-uniform mesh size; here we use uniform
gmsh.model.mesh.generate(2)  # Generate a 2D mesh

# Save the mesh to a file (e.g., in .msh format)
gmsh.write("unit_square.msh")

# Finalize and close the Gmsh API
gmsh.finalize()

# %%
import gmsh

# Initialize Gmsh
gmsh.initialize()

# Open the mesh file
gmsh.open("unit_square.msh")

# Extract node data
node_tags, node_coords, _ = gmsh.model.mesh.getNodes()

# node_tags: list of node IDs (integers)
# node_coords: list of node coordinates (flattened list: x1, y1, z1, x2, y2, z2, ...)
# The z-coordinates will be 0 for a 2D mesh

# Convert the node coordinates into a list of tuples (x, y, z)
nodes = [(node_coords[i], node_coords[i+1], node_coords[i+2]) for i in range(0, len(node_coords), 3)]

# Print node information
print("Nodes:")
for tag, coord in zip(node_tags, nodes):
    print(f"Node {tag}: {coord}")

# Extract element data (triangular elements)
element_types, element_tags, element_node_tags = gmsh.model.mesh.getElements()

# element_types: list of element types (e.g., 2 is for lines, 3 is for triangles)
# element_tags: list of element IDs (integers)
# element_node_tags: connectivity of nodes for each element (flattened list)

# We are interested in triangles, which have type 2 (for triangles in 2D)
# element_node_tags is a list of node indices defining the triangular elements
triangle_nodes = element_node_tags[1]  # Assuming the second element type corresponds to triangles

# Convert the flattened node list into tuples of three nodes (triangles)
triangles = [(triangle_nodes[i], triangle_nodes[i+1], triangle_nodes[i+2]) for i in range(0, len(triangle_nodes), 3)]

# Print triangle element information
print("\nTriangles:")
for triangle in triangles:
    print(f"Triangle with nodes: {triangle}")

# Finalize Gmsh
gmsh.finalize()
# Out:
# Nodes:
# Node 1: (np.float64(0.0), np.float64(0.0), np.float64(0.0))
# Node 2: (np.float64(1.0), np.float64(0.0), np.float64(0.0))
# Node 3: (np.float64(1.0), np.float64(1.0), np.float64(0.0))
# Node 4: (np.float64(0.0), np.float64(1.0), np.float64(0.0))
# Node 5: (np.float64(0.1249999999997731), np.float64(0.0), np.float64(0.0))
# Node 6: (np.float64(0.2499999999994107), np.float64(0.0), np.float64(0.0))
# Node 7: (np.float64(0.374999999999046), np.float64(0.0), np.float64(0.0))
# Node 8: (np.float64(0.4999999999986922), np.float64(0.0), np.float64(0.0))
# Node 84: (np.float64(0.798911060560468), np.float64(0.2500733495358767), np.float64(0.0))
# Node 85: (np.float64(0.3260733379406422), np.float64(0.6776011426060614), np.float64(0.0))
# Node 86: (np.float64(0.915464298762109), np.float64(0.4374999999988691), np.float64(0.0))
# Node 87: (np.float64(0.3281595767788002), np.float64(0.4577243358118346), np.float64(0.0))
# Node 88: (np.float64(0.9226624454759008), np.float64(0.6874999999991755), np.float64(0.0))
# Node 89: (np.float64(0.09150635094649474), np.float64(0.9084936490535108), np.float64(0.0))
# Node 90: (np.float64(0.9084936490536323), np.float64(0.9084936490536777), np.float64(0.0))
# Node 91: (np.float64(0.09150635094641771), np.float64(0.09150635094661808), np.float64(0.0))
# Node 92: (np.float64(0.9084936490535543), np.float64(0.09150635094629629), np.float64(0.0))
# Node 93: (np.float64(0.2698281199876337), np.float64(0.5654465081585689), np.float64(0.0))
# Node 94: (np.float64(0.6249999999989257), np.float64(0.1752404735813553), np.float64(0.0))
# Node 95: (np.float64(0.4999999999993445), np.float64(0.1752404735815074), np.float64(0.0))
# Node 96: (np.float64(0.3750000000023251), np.float64(0.1752404735838433), np.float64(0.0))
# Node 97: (np.float64(0.7398391675636549), np.float64(0.1753067707867464), np.float64(0.0))
# Node 98: (np.float64(0.2510355733930932), np.float64(0.1746449973844662), np.float64(0.0))
#
# Triangles:
# Triangle with nodes: (np.uint64(37), np.uint64(68), np.uint64(79))
# Triangle with nodes: (np.uint64(68), np.uint64(37), np.uint64(72))
# Triangle with nodes: (np.uint64(62), np.uint64(34), np.uint64(69))
# Triangle with nodes: (np.uint64(59), np.uint64(40), np.uint64(63))
# Triangle with nodes: (np.uint64(34), np.uint64(62), np.uint64(70))
# Triangle with nodes: (np.uint64(63), np.uint64(40), np.uint64(86))
# Triangle with nodes: (np.uint64(28), np.uint64(29), np.uint64(71))
# Triangle with nodes: (np.uint64(65), np.uint64(41), np.uint64(67))
# Triangle with nodes: (np.uint64(67), np.uint64(38), np.uint64(73))
# Triangle with nodes: (np.uint64(41), np.uint64(65), np.uint64(88))
# Triangle with nodes: (np.uint64(29), np.uint64(34), np.uint64(71))
# Triangle with nodes: (np.uint64(37), np.uint64(28), np.uint64(71))
# Triangle with nodes: (np.uint64(64), np.uint64(36), np.uint64(65))
# Triangle with nodes: (np.uint64(63), np.uint64(36), np.uint64(64))
# Triangle with nodes: (np.uint64(66), np.uint64(49), np.uint64(77))
# Triangle with nodes: (np.uint64(66), np.uint64(67), np.uint64(73))
# Triangle with nodes: (np.uint64(68), np.uint64(42), np.uint64(79))
# Triangle with nodes: (np.uint64(34), np.uint64(70), np.uint64(71))
# Triangle with nodes: (np.uint64(64), np.uint64(66), np.uint64(77))
# Triangle with nodes: (np.uint64(49), np.uint64(66), np.uint64(73))
# Triangle with nodes: (np.uint64(71), np.uint64(70), np.uint64(93))
# Triangle with nodes: (np.uint64(72), np.uint64(71), np.uint64(93))
# Triangle with nodes: (np.uint64(62), np.uint64(69), np.uint64(83))
# Triangle with nodes: (np.uint64(40), np.uint64(59), np.uint64(84))
# Triangle with nodes: (np.uint64(64), np.uint64(65), np.uint64(66))
# Triangle with nodes: (np.uint64(43), np.uint64(81), np.uint64(84))
# Triangle with nodes: (np.uint64(43), np.uint64(84), np.uint64(97))
# Triangle with nodes: (np.uint64(68), np.uint64(72), np.uint64(85))
# Triangle with nodes: (np.uint64(37), np.uint64(71), np.uint64(72))
# Triangle with nodes: (np.uint64(66), np.uint64(65), np.uint64(67))
# Triangle with nodes: (np.uint64(38), np.uint64(67), np.uint64(82))
# Triangle with nodes: (np.uint64(33), np.uint64(45), np.uint64(46))
# Triangle with nodes: (np.uint64(33), np.uint64(23), np.uint64(45))
# Triangle with nodes: (np.uint64(34), np.uint64(30), np.uint64(69))
# Triangle with nodes: (np.uint64(22), np.uint64(23), np.uint64(33))
# Triangle with nodes: (np.uint64(45), np.uint64(42), np.uint64(68))
# Triangle with nodes: (np.uint64(29), np.uint64(30), np.uint64(34))
# Triangle with nodes: (np.uint64(73), np.uint64(38), np.uint64(76))
# Triangle with nodes: (np.uint64(38), np.uint64(21), np.uint64(76))
# Triangle with nodes: (np.uint64(24), np.uint64(42), np.uint64(45))
# Triangle with nodes: (np.uint64(22), np.uint64(33), np.uint64(76))
# Triangle with nodes: (np.uint64(35), np.uint64(9), np.uint64(74))
# Triangle with nodes: (np.uint64(15), np.uint64(16), np.uint64(36))
# Triangle with nodes: (np.uint64(31), np.uint64(44), np.uint64(69))
# Triangle with nodes: (np.uint64(8), np.uint64(9), np.uint64(35))
# Triangle with nodes: (np.uint64(21), np.uint64(22), np.uint64(76))
# Triangle with nodes: (np.uint64(23), np.uint64(24), np.uint64(45))
# Triangle with nodes: (np.uint64(39), np.uint64(7), np.uint64(75))
# Triangle with nodes: (np.uint64(33), np.uint64(46), np.uint64(47))
# Triangle with nodes: (np.uint64(30), np.uint64(31), np.uint64(69))
# Triangle with nodes: (np.uint64(8), np.uint64(35), np.uint64(75))
# Triangle with nodes: (np.uint64(33), np.uint64(47), np.uint64(76))
# Triangle with nodes: (np.uint64(10), np.uint64(43), np.uint64(74))
# Triangle with nodes: (np.uint64(7), np.uint64(8), np.uint64(75))
# Triangle with nodes: (np.uint64(24), np.uint64(25), np.uint64(42))
# Triangle with nodes: (np.uint64(47), np.uint64(73), np.uint64(76))
# Triangle with nodes: (np.uint64(46), np.uint64(45), np.uint64(68))
# Triangle with nodes: (np.uint64(9), np.uint64(10), np.uint64(74))
# Triangle with nodes: (np.uint64(17), np.uint64(18), np.uint64(41))
# Triangle with nodes: (np.uint64(31), np.uint64(32), np.uint64(44))
# Triangle with nodes: (np.uint64(10), np.uint64(11), np.uint64(43))
# Triangle with nodes: (np.uint64(6), np.uint64(7), np.uint64(39))
# Triangle with nodes: (np.uint64(47), np.uint64(46), np.uint64(48))
# Triangle with nodes: (np.uint64(57), np.uint64(64), np.uint64(77))
# Triangle with nodes: (np.uint64(61), np.uint64(55), np.uint64(62))
# Triangle with nodes: (np.uint64(57), np.uint64(63), np.uint64(64))
# Triangle with nodes: (np.uint64(13), np.uint64(14), np.uint64(40))
# Triangle with nodes: (np.uint64(27), np.uint64(28), np.uint64(37))
# Triangle with nodes: (np.uint64(50), np.uint64(48), np.uint64(51))
# Triangle with nodes: (np.uint64(54), np.uint64(52), np.uint64(55))
# Triangle with nodes: (np.uint64(47), np.uint64(49), np.uint64(73))
# Triangle with nodes: (np.uint64(57), np.uint64(59), np.uint64(63))
# Triangle with nodes: (np.uint64(53), np.uint64(56), np.uint64(57))
# Triangle with nodes: (np.uint64(50), np.uint64(51), np.uint64(52))
# Triangle with nodes: (np.uint64(47), np.uint64(48), np.uint64(49))
# Triangle with nodes: (np.uint64(54), np.uint64(55), np.uint64(58))
# Triangle with nodes: (np.uint64(20), np.uint64(21), np.uint64(38))
# Triangle with nodes: (np.uint64(57), np.uint64(56), np.uint64(59))
# Triangle with nodes: (np.uint64(49), np.uint64(48), np.uint64(50))
# Triangle with nodes: (np.uint64(53), np.uint64(52), np.uint64(54))
# Triangle with nodes: (np.uint64(50), np.uint64(52), np.uint64(53))
# Triangle with nodes: (np.uint64(53), np.uint64(54), np.uint64(56))
# Triangle with nodes: (np.uint64(58), np.uint64(55), np.uint64(61))
# Triangle with nodes: (np.uint64(53), np.uint64(57), np.uint64(77))
# Triangle with nodes: (np.uint64(49), np.uint64(50), np.uint64(77))
# Triangle with nodes: (np.uint64(50), np.uint64(53), np.uint64(77))
# Triangle with nodes: (np.uint64(59), np.uint64(56), np.uint64(60))
# Triangle with nodes: (np.uint64(54), np.uint64(58), np.uint64(78))
# Triangle with nodes: (np.uint64(56), np.uint64(54), np.uint64(78))
# Triangle with nodes: (np.uint64(60), np.uint64(56), np.uint64(78))
# Triangle with nodes: (np.uint64(70), np.uint64(62), np.uint64(87))
# Triangle with nodes: (np.uint64(44), np.uint64(80), np.uint64(98))
# Triangle with nodes: (np.uint64(83), np.uint64(44), np.uint64(98))
# Triangle with nodes: (np.uint64(26), np.uint64(27), np.uint64(79))
# Triangle with nodes: (np.uint64(5), np.uint64(6), np.uint64(80))
# Triangle with nodes: (np.uint64(12), np.uint64(13), np.uint64(81))
# Triangle with nodes: (np.uint64(36), np.uint64(63), np.uint64(86))
# Triangle with nodes: (np.uint64(19), np.uint64(20), np.uint64(82))
# Triangle with nodes: (np.uint64(20), np.uint64(38), np.uint64(82))
# Triangle with nodes: (np.uint64(65), np.uint64(36), np.uint64(88))
# Triangle with nodes: (np.uint64(27), np.uint64(37), np.uint64(79))
# Triangle with nodes: (np.uint64(6), np.uint64(39), np.uint64(80))
# Triangle with nodes: (np.uint64(13), np.uint64(40), np.uint64(81))
# Triangle with nodes: (np.uint64(87), np.uint64(51), np.uint64(93))
# Triangle with nodes: (np.uint64(67), np.uint64(41), np.uint64(82))
# Triangle with nodes: (np.uint64(51), np.uint64(48), np.uint64(85))
# Triangle with nodes: (np.uint64(46), np.uint64(68), np.uint64(85))
# Triangle with nodes: (np.uint64(15), np.uint64(36), np.uint64(86))
# Triangle with nodes: (np.uint64(40), np.uint64(14), np.uint64(86))
# Triangle with nodes: (np.uint64(62), np.uint64(55), np.uint64(87))
# Triangle with nodes: (np.uint64(52), np.uint64(51), np.uint64(87))
# Triangle with nodes: (np.uint64(36), np.uint64(16), np.uint64(88))
# Triangle with nodes: (np.uint64(17), np.uint64(41), np.uint64(88))
# Triangle with nodes: (np.uint64(4), np.uint64(26), np.uint64(89))
# Triangle with nodes: (np.uint64(3), np.uint64(19), np.uint64(90))
# Triangle with nodes: (np.uint64(1), np.uint64(5), np.uint64(91))
# Triangle with nodes: (np.uint64(32), np.uint64(1), np.uint64(91))
# Triangle with nodes: (np.uint64(2), np.uint64(12), np.uint64(92))
# Triangle with nodes: (np.uint64(11), np.uint64(2), np.uint64(92))
# Triangle with nodes: (np.uint64(25), np.uint64(4), np.uint64(89))
# Triangle with nodes: (np.uint64(18), np.uint64(3), np.uint64(90))
# Triangle with nodes: (np.uint64(51), np.uint64(85), np.uint64(93))
# Triangle with nodes: (np.uint64(61), np.uint64(62), np.uint64(83))
# Triangle with nodes: (np.uint64(69), np.uint64(44), np.uint64(83))
# Triangle with nodes: (np.uint64(59), np.uint64(60), np.uint64(84))
# Triangle with nodes: (np.uint64(70), np.uint64(87), np.uint64(93))
# Triangle with nodes: (np.uint64(48), np.uint64(46), np.uint64(85))
# Triangle with nodes: (np.uint64(81), np.uint64(40), np.uint64(84))
# Triangle with nodes: (np.uint64(14), np.uint64(15), np.uint64(86))
# Triangle with nodes: (np.uint64(55), np.uint64(52), np.uint64(87))
# Triangle with nodes: (np.uint64(85), np.uint64(72), np.uint64(93))
# Triangle with nodes: (np.uint64(12), np.uint64(81), np.uint64(92))
# Triangle with nodes: (np.uint64(26), np.uint64(79), np.uint64(89))
# Triangle with nodes: (np.uint64(5), np.uint64(80), np.uint64(91))
# Triangle with nodes: (np.uint64(16), np.uint64(17), np.uint64(88))
# Triangle with nodes: (np.uint64(42), np.uint64(25), np.uint64(89))
# Triangle with nodes: (np.uint64(41), np.uint64(18), np.uint64(90))
# Triangle with nodes: (np.uint64(44), np.uint64(32), np.uint64(91))
# Triangle with nodes: (np.uint64(43), np.uint64(11), np.uint64(92))
# Triangle with nodes: (np.uint64(19), np.uint64(82), np.uint64(90))
# Triangle with nodes: (np.uint64(60), np.uint64(94), np.uint64(97))
# Triangle with nodes: (np.uint64(39), np.uint64(75), np.uint64(96))
# Triangle with nodes: (np.uint64(94), np.uint64(78), np.uint64(95))
# Triangle with nodes: (np.uint64(35), np.uint64(74), np.uint64(94))
# Triangle with nodes: (np.uint64(35), np.uint64(94), np.uint64(95))
# Triangle with nodes: (np.uint64(78), np.uint64(58), np.uint64(95))
# Triangle with nodes: (np.uint64(75), np.uint64(35), np.uint64(95))
# Triangle with nodes: (np.uint64(60), np.uint64(78), np.uint64(94))
# Triangle with nodes: (np.uint64(58), np.uint64(61), np.uint64(96))
# Triangle with nodes: (np.uint64(95), np.uint64(58), np.uint64(96))
# Triangle with nodes: (np.uint64(75), np.uint64(95), np.uint64(96))
# Triangle with nodes: (np.uint64(94), np.uint64(74), np.uint64(97))
# Triangle with nodes: (np.uint64(74), np.uint64(43), np.uint64(97))
# Triangle with nodes: (np.uint64(79), np.uint64(42), np.uint64(89))
# Triangle with nodes: (np.uint64(81), np.uint64(43), np.uint64(92))
# Triangle with nodes: (np.uint64(80), np.uint64(44), np.uint64(91))
# Triangle with nodes: (np.uint64(96), np.uint64(61), np.uint64(98))
# Triangle with nodes: (np.uint64(39), np.uint64(96), np.uint64(98))
# Triangle with nodes: (np.uint64(82), np.uint64(41), np.uint64(90))
# Triangle with nodes: (np.uint64(80), np.uint64(39), np.uint64(98))
# Triangle with nodes: (np.uint64(84), np.uint64(60), np.uint64(97))
# Triangle with nodes: (np.uint64(61), np.uint64(83), np.uint64(98))
